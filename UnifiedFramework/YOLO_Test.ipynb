# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO("yolov8m.pt")  # Load an official Detect model

# Perform tracking with the model
results = model.track("vtest.avi", show=False)  # Tracking with default tracker
#results = model.track("vtest.avi", show=False, tracker="bytetrack.yaml")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/795) /Users/hartda23/Documents/Sperm_Object_Tracking/UnifiedFramework/vtest.avi: 480x640 3 persons, 1 car, 1 truck, 212.4ms
# video 1/1 (frame 2/795) /Users/hartda23/Documents/Sperm_Object_Tracking/UnifiedFramework/vtest.avi: 480x640 3 persons, 1 car, 1 truck, 192.4ms
# video 1/1 (frame 3/795) /Users/hartda23/Documents/Sperm_Object_Tracking/UnifiedFramework/vtest.avi: 480x640 3 persons, 1 car, 1 truck, 196.1ms
# ...
